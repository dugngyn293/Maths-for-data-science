# %% [markdown]
# First we import some packages we need

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Now we define some functions

# %%
def logistic(x):
    return 1 / (1 + np.exp(-x))

# Define the logit function
def logit(x):
    return np.log(x / (1 - x))

# %% [markdown]
# now this is some value to check my definition of functions

# %%
# we will evaluate a couple of values
print(logistic(2))

print(logit(0.8))

# We will also do another test involving a random value
from numpy import random

n = random.rand()
a = logit(n)
b = logistic(a)
print(n,b)
# Out:
# 0.8807970779778823
# 1.3862943611198908
# 0.4887613207119966 0.4887613207119966

# %% [markdown]
# next is plotting. I will create a range of x values for the logistic function

# %%
x_values_logistic = np.linspace(-10, 10, 400)

# %% [markdown]
# I will create a range of y values for the logit function (0.01 to 0.99 to avoid division by zero)

# %%
x_values_logit = np.linspace(0.01, 0.99, 400)

# %% [markdown]
# Calculate the corresponding y values for both functions

# %%
logistic_values = logistic(x_values_logistic)
logit_values = logit(x_values_logit)

# %% [markdown]
# I plot logistic function and logit function

# %%
plt.plot(x_values_logistic, logistic_values, label='logistic(x)', color='blue')

# Plot the logit function
plt.plot(logit_values, x_values_logit, label='logit(x)', color='orange')
# Plot the diagonal y = x
plt.plot(x_values_logistic, x_values_logistic, label='y = x', linestyle='--', color='green')

# Add titles and labels
plt.title('Logistic and Logit Functions')
plt.xlabel('x')
plt.ylabel('Function values')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# Plot the diagonal y = x
